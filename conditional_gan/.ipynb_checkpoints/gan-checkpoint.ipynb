# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Dense, Input, Conv2D, Conv2DTranspose, LeakyReLU, \
                                    BatchNormalization, Reshape, Activation, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

from tqdm import tqdm_notebook

# %%
tf.enable_eager_execution()

# %% [markdown]
# First, we will prepare (real data)

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %%
X = np.concatenate((X_train, X_test), axis=0).astype(np.float32)
print(X.shape)
y = np.concatenate((y_train, y_test), axis=0).astype(np.float32)
print(y.shape)
# Out:
# (70000, 28, 28)
# (70000,)

# %%
X = (X - 127.5) / 255.
X = np.expand_dims(X, axis=-1)
print(X.shape)
y = y.reshape(-1, 1)
print(y.shape)
# Out:
# (70000, 28, 28, 1)
# (70000, 1)

# %% [markdown]
# Seems our (real data) is ready

# %% [markdown]
# Let's focus on making the generator and discriminator for our GAN

# %%
z_dim = 200

# %%
def build_generator():
    
    model = Sequential()
    model.add( Dense(7 * 7 * 256, input_shape=(z_dim, )) )
    model.add( Reshape((7, 7, 256)) )
    assert model.output_shape[1:] == (7, 7, 256)
    
    model.add( Conv2DTranspose(128, kernel_size=3, strides=2, padding='same') )
    model.add( BatchNormalization() )
    model.add( LeakyReLU(alpha=0.05) )
    assert model.output_shape[1:] == (14, 14, 128)
    
    model.add( Conv2DTranspose(64, kernel_size=3, strides=1, padding='same') )
    model.add( BatchNormalization() )
    model.add( LeakyReLU(alpha=0.05) )
    assert model.output_shape[1:] == (14, 14, 64)
    
    model.add( Conv2DTranspose(1, kernel_size=3, strides=2, padding='same') )
    model.add( Activation('tanh') )
    assert model.output_shape[1:] == (28, 28, 1)
    
    return model

# %%
def build_discriminator():
    
    model = Sequential()
    model.add( Conv2D(32, kernel_size=3, strides=2, input_shape=(28, 28, 1), padding='same') )
    model.add( BatchNormalization() )
    model.add( LeakyReLU(alpha=0.05) )
    assert model.output_shape[1:] == (14, 14, 32)
    
    model.add( Conv2D(64, kernel_size=3, strides=2, padding='same') )
    model.add( BatchNormalization() )
    model.add( LeakyReLU(alpha=0.05) )
    assert model.output_shape[1:] == (7, 7, 64)
    
    model.add( Conv2D(128, kernel_size=3, strides=2, padding='same') )
    model.add( BatchNormalization() )
    model.add( LeakyReLU(alpha=0.05) )
    
    model.add( Flatten() )
    model.add( Dense(1, activation='sigmoid') )
    return model

# %%
def build_gan(generator, discriminator):
    
    model = Sequential()
    model.add( generator )
    model.add( discriminator )
    return model

# %%
discriminator = build_discriminator()
discriminator.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])

generator = build_generator()
discriminator.trainable = False

gan = build_gan(generator, discriminator)
gan.compile(loss='binary_crossentropy', optimizer=Adam())

# %%
print('GENERATOR')
print(generator.summary())
# Out:
# GENERATOR
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 12544)             2521344
# _________________________________________________________________
# reshape (Reshape)            (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 128)       295040
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 14, 14, 64)        73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 28, 28, 1)         577
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 1)         0
# =================================================================
# Total params: 2,891,521
# Trainable params: 2,891,137
# Non-trainable params: 384
# _________________________________________________________________
# None

# %%
print('DISCRIMINATOR')
print(discriminator.summary())
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0624 15:20:33.294913 140199779424000 training.py:2197] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# DISCRIMINATOR
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 14, 14, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 14, 14, 32)        128
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 64)          18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 7, 7, 64)          256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 2049
# =================================================================
# Total params: 190,786
# Trainable params: 95,169
# Non-trainable params: 95,617
# _________________________________________________________________
# None

# %%
print('GAN')
print(gan.summary())
# Out:
# GAN
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 28, 28, 1)         2891521
# _________________________________________________________________
# sequential (Sequential)      (None, 1)                 95617
# =================================================================
# Total params: 2,987,138
# Trainable params: 2,891,137
# Non-trainable params: 96,001
# _________________________________________________________________
# None

# %% [markdown]
# This is the most important piece of code. We do the following:-
#
# We make a discriminator, compile it for use. Now, we use the untrainable version of the same discriminator (with same weights) in the gan. SO, for gan, only generator is trainable

# %%
z_sample = np.random.normal(size=(2, z_dim)).astype(np.float32)
gen_imgs = generator.predict(z_sample)
discriminator_output = discriminator(gen_imgs)

# %%
def sample_images(generator, image_grid_rows=4, image_grid_columns=4, epoch=None):

    # Sample random noise
    z = np.random.normal(0, 1, (image_grid_rows * image_grid_columns, z_dim))

    # Generate images from random noise
    gen_imgs = generator.predict(z)

    # Rescale image pixel values to [0, 1]
    gen_imgs = 0.5 * gen_imgs + 0.5

    # Set image grid
    fig, axs = plt.subplots(image_grid_rows,
                            image_grid_columns,
                            figsize=(4, 4),
                            sharey=True,
                            sharex=True)

    cnt = 0
    for i in range(image_grid_rows):
        for j in range(image_grid_columns):
            # Output a grid of images
            axs[i, j].imshow(gen_imgs[cnt, :, :, 0], cmap='gray')
            axs[i, j].axis('off')
            cnt += 1
            
    if epoch:
        plt.savefig(str(epoch) + '.jpg')
    plt.show()
    plt.close(fig)

# %%
sample_images(generator, image_grid_rows=2, image_grid_columns=2)

# %%
gen_losses = []

disc_losses = []
disc_accuracies = []

# %%
def train(num_epochs=100, batch_size=32):
    
    real = np.ones(shape=(batch_size, 1))
    fake = np.zeros(shape=(batch_size, 1))
    
    num_imgs = X.shape[0]
    
    for epoch in range(num_epochs):
        
        num_batches = num_imgs // batch_size
        
        batch_gen_loss = []
        batch_disc_loss = []
        batch_disc_acc = []
        
        for i in tqdm_notebook(range(num_batches)):
        
            idxs = np.random.randint(low=0, high=num_imgs, size=batch_size)
            real_imgs = X[idxs]

            z = np.random.normal(size=(batch_size, z_dim)).astype(np.float32)
            gen_imgs = generator(z)

            d_loss1, d_acc1 = discriminator.train_on_batch(real_imgs, real)
            d_loss2, d_acc2 = discriminator.train_on_batch(gen_imgs, fake)
            d_loss, d_acc = 0.5 * (d_loss1 + d_loss2), 0.5 * (d_acc1 + d_acc2)

            g_loss = gan.train_on_batch(z, real)

            batch_gen_loss.append(g_loss)
            batch_disc_loss.append(d_loss)
            batch_disc_acc.append(d_acc)
        
        print('Epoch {}, generator loss = {}, discriminator loss/acc = {}/{}'.format(
            epoch, np.mean(batch_gen_loss), np.mean(batch_disc_loss), np.mean(batch_disc_acc)*100.))
        sample_images(generator, image_grid_rows=3, image_grid_columns=3, epoch=epoch)
        
        gen_losses.append( np.mean(batch_gen_loss) )
        disc_losses.append( np.mean(batch_disc_loss) )
        disc_accuracies.append( np.mean(batch_disc_acc) )

# %%
train(batch_size=32)
# Out:
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# W0624 15:20:35.592522 140199779424000 training.py:2197] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# W0624 15:20:35.689850 140199779424000 deprecation.py:323] From /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0624 15:20:36.912359 140199779424000 training.py:2197] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Epoch 0, generator loss = 4.6808600425720215, discriminator loss/acc = 0.06773106076603827/98.26460333790581
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 1, generator loss = 5.391073226928711, discriminator loss/acc = 0.06317233751044311/97.96382030178327
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 2, generator loss = 5.263892650604248, discriminator loss/acc = 0.08078061639062786/97.32724622770918
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 3, generator loss = 5.5586018562316895, discriminator loss/acc = 0.06506978896965844/97.77377686328303
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch
0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-09b9d52f9b7b> in <module>
# ----> 1 train(batch_size=32)
#
# <ipython-input-19-1a3e7e395cf4> in train(num_epochs, batch_size)
#      20
#      21             z = np.random.normal(size=(batch_size, z_dim)).astype(np.float32)
# ---> 22             gen_imgs = generator(z)
#      23
#      24             d_loss1, d_acc1 = discriminator.train_on_batch(real_imgs, real)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     677           with base_layer_utils.autocast_context_manager(
#     678               input_list, self._mixed_precision_policy.should_cast_variables):
# --> 679             outputs = self.call(inputs, *args, **kwargs)
#     680           self._handle_activity_regularization(inputs, outputs)
#     681           self._set_mask_metadata(inputs, outputs, previous_mask)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/sequential.py in call(self, inputs, training, mask)
#     245       if not self.built:
#     246         self._init_graph_network(self.inputs, self.outputs, name=self.name)
# --> 247       return super(Sequential, self).call(inputs, training=training, mask=mask)
#     248
#     249     outputs = inputs  # handle the corner case where self.layers is empty
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/network.py in call(self, inputs, training, mask)
#     749                                 ' implement a `call` method.')
#     750
# --> 751     return self._run_internal_graph(inputs, training=training, mask=mask)
#     752
#     753   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask)
#     891
#     892           # Compute outputs.
# --> 893           output_tensors = layer(computed_tensors, **kwargs)
#     894
#     895           # Update tensor_dict.
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     677           with base_layer_utils.autocast_context_manager(
#     678               input_list, self._mixed_precision_policy.should_cast_variables):
# --> 679             outputs = self.call(inputs, *args, **kwargs)
#     680           self._handle_activity_regularization(inputs, outputs)
#     681           self._set_mask_metadata(inputs, outputs, previous_mask)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/keras/layers/convolutional.py in call(self, inputs)
#     784       h_axis, w_axis = 1, 2
#     785
# --> 786     height, width = inputs_shape[h_axis], inputs_shape[w_axis]
#     787     kernel_h, kernel_w = self.kernel_size
#     788     stride_h, stride_w = self.strides
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     654     if begin:
#     655       packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
# --> 656                                                   stack(strides))
#     657       if (packed_begin.dtype == dtypes.int64 or
#     658           packed_end.dtype == dtypes.int64 or
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/array_ops.py in stack(values, axis, name)
#    1033     try:
#    1034       # If the input is a constant list, it can be converted to a constant op
# -> 1035       return ops.convert_to_tensor(values, name=name)
#    1036     except (TypeError, ValueError):
#    1037       pass  # Input list contains non-constant tensors
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1085   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1086       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1087   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1088
#    1089
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1143       name=name,
#    1144       preferred_dtype=dtype_hint,
# -> 1145       as_ref=False)
#    1146
#    1147
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx, accept_symbolic_tensors, accept_composite_tensors)
#    1222
#    1223     if ret is None:
# -> 1224       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1225
#    1226     if ret is NotImplemented:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     303                                          as_ref=False):
#     304   _ = as_ref
# --> 305   return constant(v, dtype=dtype, name=name)
#     306
#     307
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     244   """
#     245   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 246                         allow_broadcast=True)
#     247
#     248
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     252   ctx = context.context()
#     253   if ctx.executing_eagerly():
# --> 254     t = convert_to_eager_tensor(value, ctx, dtype)
#     255     if shape is None:
#     256       return t
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     113     return t
#     114   else:
# --> 115     return ops.EagerTensor(value, handle, device, dtype)
#     116
#     117
#
# KeyboardInterrupt:

# %%
plt.plot(disc_losses, label='Discriminator')
plt.plot(gen_losses, label='Generator')
plt.legend()
plt.title('losses')
plt.show()

# %%
def train(num_epochs=100, batch_size=32):
    
    real = np.ones(shape=(batch_size, 1)) * 0.9
    fake = np.ones(shape=(batch_size, 1)) * 0.1
    
    num_imgs = X.shape[0]
    
    for epoch in range(num_epochs):
        
        num_batches = num_imgs // batch_size
        
        batch_gen_loss = []
        batch_disc_loss = []
        batch_disc_acc = []
        
        for i in tqdm_notebook(range(num_batches)):
        
            idxs = np.random.randint(low=0, high=num_imgs, size=batch_size)
            real_imgs = X[idxs]

            z = np.random.normal(size=(batch_size, z_dim)).astype(np.float32)
            gen_imgs = generator(z)

            d_loss1, d_acc1 = discriminator.train_on_batch(real_imgs, real)
            d_loss2, d_acc2 = discriminator.train_on_batch(gen_imgs, fake)
            d_loss, d_acc = 0.5 * (d_loss1 + d_loss2), 0.5 * (d_acc1 + d_acc2)

            g_loss = gan.train_on_batch(z, real)

            batch_gen_loss.append(g_loss)
            batch_disc_loss.append(d_loss)
            batch_disc_acc.append(d_acc)
        
        print('Epoch {}, generator loss = {}, discriminator loss/acc = {}/{}'.format(
            epoch, np.mean(batch_gen_loss), np.mean(batch_disc_loss), np.mean(batch_disc_acc)*100.))
        sample_images(generator, image_grid_rows=3, image_grid_columns=3, epoch=epoch)
        
        gen_losses.append( np.mean(batch_gen_loss) )
        disc_losses.append( np.mean(batch_disc_loss) )
        disc_accuracies.append( np.mean(batch_disc_acc) )

# %%
train(batch_size=32)
# Out:
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# W0624 16:31:54.301201 140199779424000 training.py:2197] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# W0624 16:31:54.310861 140199779424000 training.py:2197] Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Epoch 0, generator loss = 13.882408142089844, discriminator loss/acc = 1.538582742186949/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 1, generator loss = 9.668143272399902, discriminator loss/acc = 1.2032747140446372/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 2, generator loss = 2.0512993335723877, discriminator loss/acc = 0.3905449817455355/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 3, generator loss = 2.0082571506500244, discriminator loss/acc = 0.3522806450499756/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 4, generator loss = 2.1233108043670654, discriminator loss/acc = 0.35103098734034544/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 5, generator loss = 2.136782646179199, discriminator loss/acc = 0.3508710003111752/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 6, generator loss = 2.129920721054077, discriminator loss/acc = 0.354012711998203/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 7, generator loss = 2.1441123485565186, discriminator loss/acc = 0.35240731107954243/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 8, generator loss = 2.144831418991089, discriminator loss/acc = 0.35086627899374/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 9, generator loss = 2.130680799484253, discriminator loss/acc = 0.35092325619654835/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 10, generator loss = 2.1625754833221436, discriminator loss/acc = 0.3513040808602234/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 11, generator loss = 2.140380382537842, discriminator loss/acc = 0.34897786744064974/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 12, generator loss = 2.1520965099334717, discriminator loss/acc = 0.3502864314777207/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 13, generator loss = 2.138434648513794, discriminator loss/acc = 0.3515770051187176/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 14, generator loss = 2.1364212036132812, discriminator loss/acc = 0.34876054780200894/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 15, generator loss = 2.131366729736328, discriminator loss/acc = 0.34602323613267105/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 16, generator loss = 2.132678985595703, discriminator loss/acc = 0.3478053168150514/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 17, generator loss = 2.1501543521881104, discriminator loss/acc = 0.34790162398055313/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 18, generator loss = 2.1356089115142822, discriminator loss/acc = 0.3485670758127676/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 19, generator loss = 2.1476454734802246, discriminator loss/acc = 0.3493639733293147/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 20, generator loss = 2.1447389125823975, discriminator loss/acc = 0.3474958784159428/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 21, generator loss = 2.1511759757995605, discriminator loss/acc = 0.3459652399548015/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 22, generator loss = 2.1498045921325684, discriminator loss/acc = 0.3472857752863435/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 23, generator loss = 2.182218551635742, discriminator loss/acc = 0.34761713270079236/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch 24, generator loss = 2.1374125480651855, discriminator loss/acc = 0.3452099236277723/0.0
# HBox(children=(IntProgress(value=0, max=2187), HTML(value='')))
# Epoch